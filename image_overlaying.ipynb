# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
zeb = cv2.imread("zebra.jpg")
disk = cv2.imread("recording.jpg")
zeb = cv2.cvtColor(zeb,cv2.COLOR_BGR2GRAY)
disk = cv2.cvtColor(disk,cv2.COLOR_BGR2GRAY)

# %%
thresh = 150
max = 255
th, dst = cv2.threshold(disk,thresh,max,cv2.THRESH_BINARY)

# %%
plt.imshow(dst[:-1],cmap='gray')

# %%
plt.imshow(zeb[:-1],cmap='gray')

# %%
zeb.shape
# Out:
# (853, 1280)

# %%
dst.shape
# Out:
# (851, 1280)

# %%
zebr = cv2.resize(zeb,(1280,800),cv2.INTER_LINEAR)
dskr = cv2.resize(disk,(1280,800),cv2.INTER_LINEAR)

# %%
zebr.shape
# Out:
# (800, 1280)

# %%
plt.imshow(zebr,cmap='gray')

# %%
plt.imshow(dskr,cmap='gray')

# %%
overlay = np.where(dskr > 150, zebr,0)

# %%
dskr.shape
# Out:
# (800, 1280)

# %%
plt.imshow(overlay,cmap='gray')

# %%
#cv2.imwrite("disk_mask.jpg",overlay)
